# %%
# !pip install deap
# Out:
# Collecting deap
#   Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deap) (1.23.5)
# Installing collected packages: deap
# Successfully installed deap-1.4.1

# %% [markdown]
# ### Setup

# %%
from deap import base, creator, tools
import random
import string
import itertools

signals = list(string.ascii_lowercase)  # Characters used to make words
meanings = list(range(0, 100))  # 100 possible meanings

creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", dict, fitness=creator.FitnessMax)

toolbox = base.Toolbox()

# def create_word(min_length=1, max_length=3):
#     length = random.randint(min_length, max_length)
#     return ''.join(random.choice(signals) for _ in range(length))

def create_word(min_length=1, max_length=3):
    length = random.randint(min_length, max_length)
    return str(random.choices(signals, weights=(8.12,1.49,2.71,4.32,12.02,2.30,2.03,5.92,7.31,0.10,0.69,3.98,2.61,6.95,7.68,1.82,0.11,6.02,6.28,9.10,2.88,1.11,2.09,0.17,2.11,0.07),k=length))


def create_individual():
    individual = creator.Individual()
    individual.local_state = random.choice(meanings)
    individual.age = 0
    for meaning in meanings:

        word = create_word()
        individual[meaning] = word

    return individual

toolbox.register("individual", create_individual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)
# Out:
# /usr/local/lib/python3.10/dist-packages/deap/creator.py:185: RuntimeWarning: A class named 'FitnessMax' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# /usr/local/lib/python3.10/dist-packages/deap/creator.py:185: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "

# %% [markdown]
# ### Evaluation

# %%
GLOBAL_STATE = random.choice(meanings)

"""
Adds newly heard word to individual's vocabulary
if a randomly guessed meaning matches that of the
speaker.
"""
def learn(individual, new_word, speakers_meaning):
    random_meaning = random.choice(meanings)
    if random_meaning == speakers_meaning:
        individual[random_meaning] = new_word

def pairwise_communication(speaker, listener, GLOBAL_STATE):
    fitness = 0
    # speaker encodes signals
    local_meaning = speaker.local_state
    global_meaning = GLOBAL_STATE

    semantic_local = speaker[local_meaning]
    semantic_global = speaker[global_meaning]

    # only update if listener has words in dictionary
    decoded_local = -100
    decoded_global = -101

    localWordPresentinListener = 0
    globalWordPresentinListener = 0
    # listener decodes local signal or possibly learns new word
    for meaning in meanings:
        if semantic_local == listener[meaning]:
            decoded_local = meaning
            localWordPresentinListener = 1
        if semantic_global == listener[meaning]:
            decoded_global = meaning
            globalWordPresentinListener = 1

    if localWordPresentinListener == 1:
        if (random.random() < 1):
            learn(listener, semantic_local, local_meaning)

    if globalWordPresentinListener == 1:
        if (random.random() < 1):
            learn(listener, semantic_global, global_meaning)

    if (decoded_local == local_meaning) & (localWordPresentinListener == 1):
        fitness += 1
    if (decoded_global == global_meaning) & (globalWordPresentinListener == 1):
        fitness += 1

    # penalty if different ideas are represented by the same word
    if local_meaning != global_meaning:
        if semantic_global == semantic_local:
            fitness -= 1
        if decoded_local == decoded_global:
            fitness -= 1

    return fitness

def survival_task(individual, GROUP_SIZE):
    penalty = 0
    for i in range(2 * (GROUP_SIZE - 1)):
        meaning1, meaning2 = random.sample(meanings, 2) # two different meanings
        if individual[meaning1] == individual[meaning2]: # same word
            penalty += 2

    return penalty

# evaluate group
def evaluate_group(group, GROUP_SIZE):
    GLOBAL_STATE = random.choice(meanings)
    # reset fitness
    for ind in group:
        # ind.fitness.values = (0,)  # reset fitness
        ind.local_state = random.choice(meanings)

    # speak
    for speaker, listener in itertools.permutations(group, 2):
        fitness_bonus = pairwise_communication(speaker, listener, GLOBAL_STATE)
        speaker.fitness.values = (speaker.fitness.values[0] + fitness_bonus,)
        listener.fitness.values = (listener.fitness.values[0] + fitness_bonus,)

    # individual survival
    for ind in group:
        penalty = survival_task(ind, GROUP_SIZE)
        ind.fitness.values = (ind.fitness.values[0] - penalty,)

# %% [markdown]
# ### Declare population + initial eval

# %%
# create pop
population = toolbox.population(n=100)

for ind in population:
    ind.fitness.values = (0,)

toolbox.register("evaluate", evaluate_group)

GROUP_SIZE = 10

# for i in range(500):
groups = [population[i:i + GROUP_SIZE] for i in range(0, len(population), GROUP_SIZE)]
for group in groups:
    toolbox.evaluate(group, GROUP_SIZE)

count = 0
for ind in population:
    if ind.fitness.values[0] > 0:
        print(ind, ind.fitness.values[0])
        count += 1
print(count)
# Out:
# {0: "['o']", 1: "['h']", 2: "['i', 'a', 'o']", 3: "['a', 'h']", 4: "['a', 'm']", 5: "['e']", 6: "['i', 'e', 'i']", 7: "['k']", 8: "['b']", 9: "['g']", 10: "['d']", 11: "['b', 'e', 'u']", 12: "['e']", 13: "['g']", 14: "['t']", 15: "['y']", 16: "['o']", 17: "['s', 'm', 'o']", 18: "['o', 'f', 'a']", 19: "['b']", 20: "['y']", 21: "['o', 'e', 'm']", 22: "['e']", 23: "['i', 'i', 'e']", 24: "['a']", 25: "['t', 'n', 't']", 26: "['a']", 27: "['s', 'e']", 28: "['y', 't']", 29: "['d', 'a', 'l']", 30: "['e', 'o']", 31: "['u', 'a', 'o']", 32: "['i']", 33: "['m', 'r']", 34: "['r', 'u', 'a']", 35: "['o']", 36: "['a']", 37: "['t']", 38: "['h', 'e']", 39: "['l']", 40: "['e']", 41: "['t', 'e', 'e']", 42: "['l', 'y']", 43: "['e', 'e']", 44: "['c', 'd']", 45: "['u', 't', 'h']", 46: "['n']", 47: "['s', 'a']", 48: "['t', 'r', 'o']", 49: "['e', 'f']", 50: "['h', 't']", 51: "['e', 'r', 'i']", 52: "['s']", 53: "['a']", 54: "['o', 't', 'e']", 55: "['h', 'r', 'e']", 56: "['a']", 57: "['t']", 58: "['e', 'd']", 59: "['e']", 60: "['n']", 61: "['r', 'q']", 62: "['f', 'e', 'p']", 63: "['f', 'i']", 64: "['m', 'o', 's']", 65: "['a', 'f']", 66: "['r', 'a', 'y']", 67: "['o', 'e']", 68: "['a', 'e', 'a']", 69: "['m', 'n', 'd']", 70: "['n', 'g', 'i']", 71: "['n', 'a', 'r']", 72: "['g']", 73: "['e']", 74: "['s']", 75: "['f', 'i']", 76: "['a', 'a', 'i']", 77: "['r', 'w']", 78: "['h']", 79: "['n']", 80: "['h', 'o']", 81: "['o', 't', 's']", 82: "['s', 'e']", 83: "['m', 'p']", 84: "['e']", 85: "['f', 'e', 'a']", 86: "['e', 'o', 'i']", 87: "['l', 'a']", 88: "['h', 'o']", 89: "['a']", 90: "['p', 't']", 91: "['c']", 92: "['a']", 93: "['r']", 94: "['e', 'h', 'e']", 95: "['c']", 96: "['r']", 97: "['h', 'w']", 98: "['p', 'i']", 99: "['y', 'm', 'l']"} 1.0
# {0: "['e']", 1: "['o', 'o']", 2: "['e', 'l', 'y']", 3: "['e', 'o', 'w']", 4: "['a']", 5: "['o']", 6: "['c', 'l', 'l']", 7: "['t']", 8: "['w', 'c']", 9: "['t', 'o']", 10: "['s', 'n', 'a']", 11: "['h', 'l', 'i']", 12: "['e', 'n', 'i']", 13: "['a', 'n']", 14: "['s', 'e']", 15: "['s', 'i', 'e']", 16: "['o', 'r']", 17: "['s', 'y']", 18: "['i', 'e', 'i']", 19: "['e', 'w']", 20: "['e', 'r']", 21: "['h', 'e', 'a']", 22: "['h']", 23: "['d']", 24: "['h', 'o']", 25: "['t']", 26: "['t', 's']", 27: "['o', 'a']", 28: "['a', 'i']", 29: "['y', 'l', 'e']", 30: "['o', 'n', 'u']", 31: "['a', 'e']", 32: "['r', 'n']", 33: "['i']", 34: "['o']", 35: "['x', 'e']", 36: "['t', 'r', 'j']", 37: "['o', 'c', 'i']", 38: "['h', 'e']", 39: "['k', 't', 'l']", 40: "['i', 'd', 'n']", 41: "['y', 'i']", 42: "['r']", 43: "['e', 'u']", 44: "['d', 'i', 'n']", 45: "['n', 'v', 'l']", 46: "['d', 'r']", 47: "['a', 'r']", 48: "['e', 'w']", 49: "['c']", 50: "['s', 's']", 51: "['s', 'n']", 52: "['d', 'c']", 53: "['c']", 54: "['e', 't', 'e']", 55: "['d', 'h', 'o']", 56: "['p']", 57: "['e', 'i']", 58: "['n', 's']", 59: "['d']", 60: "['w', 'b']", 61: "['t']", 62: "['d', 'i', 'd']", 63: "['v', 'l', 'i']", 64: "['t', 'u']", 65: "['u']", 66: "['a', 's']", 67: "['b', 'd', 'l']", 68: "['o']", 69: "['a', 'u']", 70: "['r', 'n', 'g']", 71: "['t', 's', 't']", 72: "['o', 'o']", 73: "['r']", 74: "['r', 'e', 'e']", 75: "['e', 'i']", 76: "['e', 'i']", 77: "['r', 'd', 'a']", 78: "['r']", 79: "['t']", 80: "['r', 'd', 'o']", 81: "['r', 'a', 'm']", 82: "['a', 'e']", 83: "['e']", 84: "['o', 'w', 'l']", 85: "['d']", 86: "['o', 'i', 'n']", 87: "['e', 'g']", 88: "['o', 's']", 89: "['i', 'o', 'e']", 90: "['r', 'p', 'k']", 91: "['n', 'o']", 92: "['r', 'e']", 93: "['l', 'w', 'x']", 94: "['t']", 95: "['p', 's', 'e']", 96: "['h', 't']", 97: "['n', 'g', 'o']", 98: "['r', 'f']", 99: "['n']"} 3.0
# 2

# %% [markdown]
# ### Params

# %%
from deap import algorithms
import numpy

# Parameters
NUM_GENERATIONS = 10000
CXPB = 0.5  # Crossover probability
MUTPB = 0.01  # Mutation probability (seems better at 0 for now or .01)

# mut for signals
def mutateInd(individual, indpb):
    for i in range(len(meanings)):
        if random.random() < indpb:
            individual[i] = create_word()

    return individual,

# tools
toolbox.register("mate", tools.cxUniform, indpb=0.5)
toolbox.register("mutate", mutateInd, indpb=0.1)
toolbox.register("select", tools.selRoulette) # inspired by paper
toolbox.register("tourn", tools.selTournament)
toolbox.register("randsel", tools.selRandom)
toolbox.register("stochastic_select", tools.selStochasticUniversalSampling)



stats = tools.Statistics(lambda ind: ind.fitness.values)
stats.register("avg", numpy.mean)
stats.register("min", numpy.min)
stats.register("max", numpy.max)

# for steady state
def select_next_generation(parents, offspring, max_age=3):
    combined = parents + offspring
    filtered = [ind for ind in combined if ind.age < max_age]
    selected = toolbox.tourn(filtered, len(population), 2)
    return selected

# %% [markdown]
# ### run algorithm

# %%
for gen in range(NUM_GENERATIONS):

    #for ES:
    MU = 100
    LAMBDA = 150

    """
    Mating selection
    """
    #offspring = toolbox.randsel(population, LAMBDA)
    #offspring = toolbox.select(population, len(population))
    #offspring = toolbox.tourn(population, len(population), tournsize=2)
    offspring = toolbox.randsel(population, len(population)) # random sel

    offspring = list(map(toolbox.clone, offspring))

    # mutation and crossover
    for child1, child2 in zip(offspring[::2], offspring[1::2]):
        if random.random() < CXPB:
            toolbox.mate(child1, child2)
            del child1.fitness.values
            del child2.fitness.values

    for mutant in offspring:
        if random.random() < MUTPB:
            toolbox.mutate(mutant)
            del mutant.fitness.values

    """
    Evaluate Fitness
    """
    random.shuffle(offspring)
    for ind in offspring:
        ind.fitness.values = (0,)
    groups = [offspring[i:i + GROUP_SIZE] for i in range(0, len(offspring), GROUP_SIZE)]
    for group in groups:
        toolbox.evaluate(group, GROUP_SIZE)

    for ind in population:
        ind.age += 1

    """
    Survivor Selection
    """
    # ES:
    #population[:] = toolbox.stochastic_select(offspring, MU)

    # steady state:
    population [:] = select_next_generation(population, offspring)

    # generational:
    #population[:] = offspring


    fits = [ind.fitness.values[0] for ind in population]


    from collections import Counter

    def count_duplicate_values(individual):
        value_count = Counter(individual.values())
        duplicates = [value for value, count in value_count.items() if count > 1]
        return len(duplicates)  # Return the number of unique values that are duplicates

    dup_list = []

    for individual in population:
        num_duplicates = count_duplicate_values(individual)
        dup_list.append(num_duplicates)

    sum_dups = 0
    for dup in dup_list:
        sum_dups += dup
    #print("Dup Avg:", sum_dups / len(ind) / len(population))



    length = len(population)
    mean = sum(fits) / length
    sum2 = sum(x*x for x in fits)
    std = abs(sum2 / length - mean**2)**0.5

    print(f"Generation {gen}: Min {min(fits)}, Max {max(fits)}, Avg {mean}, Std {std}, Avg % of duplicate genes across participants {sum_dups / len(ind) / len(population)}")

# print final pop
for ind in population:
    print(ind, ind.fitness.values)
# Out:
# Streaming output truncated to the last 5000 lines.
# Generation 5100: Min 35.0, Max 36.0, Avg 35.96, Std 0.1959591794224259, Avg % of duplicate genes across participants 0.0203
# Generation 5101: Min 34.0, Max 36.0, Avg 35.94, Std 0.2764054992219742, Avg % of duplicate genes across participants 0.0202
# Generation 5102: Min 35.0, Max 36.0, Avg 35.91, Std 0.28618176042531507, Avg % of duplicate genes across participants 0.0204
# Generation 5103: Min 27.0, Max 36.0, Avg 35.64, Std 1.2924395537122704, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5104: Min 35.0, Max 36.0, Avg 35.93, Std 0.2551470164435192, Avg % of duplicate genes across participants 0.02
# Generation 5105: Min 34.0, Max 36.0, Avg 35.96, Std 0.2799999999997752, Avg % of duplicate genes across participants 0.02
# Generation 5106: Min 35.0, Max 36.0, Avg 35.87, Std 0.3363034344163893, Avg % of duplicate genes across participants 0.02
# Generation 5107: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.02
# Generation 5108: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.02
# Generation 5109: Min 34.0, Max 36.0, Avg 35.93, Std 0.2917190429163158, Avg % of duplicate genes across participants 0.02
# Generation 5110: Min 34.0, Max 36.0, Avg 35.9, Std 0.3316624790357319, Avg % of duplicate genes across participants 0.02
# Generation 5111: Min 18.0, Max 36.0, Avg 35.62, Std 2.274994505487927, Avg % of duplicate genes across participants 0.02
# Generation 5112: Min 34.0, Max 36.0, Avg 35.87, Std 0.36482872693942353, Avg % of duplicate genes across participants 0.0207
# Generation 5113: Min 35.0, Max 36.0, Avg 35.89, Std 0.31288975694321064, Avg % of duplicate genes across participants 0.0203
# Generation 5114: Min 18.0, Max 36.0, Avg 35.64, Std 2.519999999999962, Avg % of duplicate genes across participants 0.02
# Generation 5115: Min 34.0, Max 36.0, Avg 35.96, Std 0.2799999999997752, Avg % of duplicate genes across participants 0.02
# Generation 5116: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.020499999999999997
# Generation 5117: Min 27.0, Max 36.0, Avg 35.64, Std 0.9951884243699324, Avg % of duplicate genes across participants 0.02
# Generation 5118: Min 34.0, Max 36.0, Avg 35.97, Std 0.22158519806201055, Avg % of duplicate genes across participants 0.02
# Generation 5119: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.02
# Generation 5120: Min 16.0, Max 36.0, Avg 35.34, Std 2.1827505583551674, Avg % of duplicate genes across participants 0.0206
# Generation 5121: Min 34.0, Max 36.0, Avg 35.48, Std 0.6997142273815143, Avg % of duplicate genes across participants 0.022099999999999998
# Generation 5122: Min 18.0, Max 36.0, Avg 35.13, Std 2.2656345689452624, Avg % of duplicate genes across participants 0.0215
# Generation 5123: Min 32.0, Max 36.0, Avg 35.6, Std 0.6928203230273999, Avg % of duplicate genes across participants 0.020499999999999997
# Generation 5124: Min 35.0, Max 36.0, Avg 35.9, Std 0.3000000000002425, Avg % of duplicate genes across participants 0.0203
# Generation 5125: Min 35.0, Max 36.0, Avg 35.86, Std 0.34698703145797516, Avg % of duplicate genes across participants 0.02
# Generation 5126: Min 34.0, Max 36.0, Avg 35.92, Std 0.36551333764978755, Avg % of duplicate genes across participants 0.02
# Generation 5127: Min 34.0, Max 36.0, Avg 35.94, Std 0.2764054992219742, Avg % of duplicate genes across participants 0.0204
# Generation 5128: Min 35.0, Max 36.0, Avg 35.9, Std 0.3000000000002425, Avg % of duplicate genes across participants 0.022000000000000002
# Generation 5129: Min 34.0, Max 36.0, Avg 35.87, Std 0.41605288125453965, Avg % of duplicate genes across participants 0.0213
# Generation 5130: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.021400000000000002
# Generation 5131: Min 34.0, Max 36.0, Avg 35.81, Std 0.4624932431936055, Avg % of duplicate genes across participants 0.0212
# Generation 5132: Min 18.0, Max 36.0, Avg 35.7, Std 1.8894443627690414, Avg % of duplicate genes across participants 0.0218
# Generation 5133: Min 34.0, Max 36.0, Avg 35.96, Std 0.24166091947166865, Avg % of duplicate genes across participants 0.0212
# Generation 5134: Min 18.0, Max 36.0, Avg 35.41, Std 2.698499583101766, Avg % of duplicate genes across participants 0.021099999999999997
# Generation 5135: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.0208
# Generation 5136: Min 33.0, Max 36.0, Avg 35.89, Std 0.4448595283905814, Avg % of duplicate genes across participants 0.0204
# Generation 5137: Min 33.0, Max 36.0, Avg 35.86, Std 0.4476605857121804, Avg % of duplicate genes across participants 0.020499999999999997
# Generation 5138: Min 35.0, Max 36.0, Avg 35.91, Std 0.28618176042531507, Avg % of duplicate genes across participants 0.02
# Generation 5139: Min 32.0, Max 36.0, Avg 35.51, Std 1.1618519699170637, Avg % of duplicate genes across participants 0.0203
# Generation 5140: Min 34.0, Max 36.0, Avg 35.98, Std 0.19899748742148488, Avg % of duplicate genes across participants 0.0206
# Generation 5141: Min 32.0, Max 36.0, Avg 35.91, Std 0.44933283877349833, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5142: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.02
# Generation 5143: Min 35.0, Max 36.0, Avg 35.93, Std 0.2551470164435192, Avg % of duplicate genes across participants 0.02
# Generation 5144: Min 34.0, Max 36.0, Avg 35.85, Std 0.4330127018922193, Avg % of duplicate genes across participants 0.02
# Generation 5145: Min 34.0, Max 36.0, Avg 35.73, Std 0.5264028875303078, Avg % of duplicate genes across participants 0.02
# Generation 5146: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.0202
# Generation 5147: Min 35.0, Max 36.0, Avg 35.9, Std 0.3000000000002425, Avg % of duplicate genes across participants 0.02
# Generation 5148: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.02
# Generation 5149: Min 34.0, Max 36.0, Avg 35.85, Std 0.455521678957195, Avg % of duplicate genes across participants 0.02
# Generation 5150: Min 34.0, Max 36.0, Avg 35.96, Std 0.24166091947166865, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5151: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.02
# Generation 5152: Min 16.0, Max 36.0, Avg 35.6, Std 2.799999999999985, Avg % of duplicate genes across participants 0.02
# Generation 5153: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.02
# Generation 5154: Min 34.0, Max 36.0, Avg 35.93, Std 0.3241913015489359, Avg % of duplicate genes across participants 0.02
# Generation 5155: Min 18.0, Max 36.0, Avg 35.68, Std 1.848675201326613, Avg % of duplicate genes across participants 0.02
# Generation 5156: Min 34.0, Max 36.0, Avg 35.83, Std 0.401372644808114, Avg % of duplicate genes across participants 0.02
# Generation 5157: Min 35.0, Max 36.0, Avg 35.92, Std 0.2712931993244851, Avg % of duplicate genes across participants 0.02
# Generation 5158: Min 32.0, Max 36.0, Avg 35.6, Std 1.095445115010249, Avg % of duplicate genes across participants 0.02
# Generation 5159: Min 34.0, Max 36.0, Avg 35.83, Std 0.401372644808114, Avg % of duplicate genes across participants 0.02
# Generation 5160: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.02
# Generation 5161: Min 17.0, Max 36.0, Avg 35.81, Std 1.8904761305025426, Avg % of duplicate genes across participants 0.02
# Generation 5162: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.02
# Generation 5163: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.02
# Generation 5164: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.02
# Generation 5165: Min 33.0, Max 36.0, Avg 35.88, Std 0.4308131845705222, Avg % of duplicate genes across participants 0.02
# Generation 5166: Min 18.0, Max 36.0, Avg 35.56, Std 2.0411761315476524, Avg % of duplicate genes across participants 0.02
# Generation 5167: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.0203
# Generation 5168: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.0208
# Generation 5169: Min 35.0, Max 36.0, Avg 35.81, Std 0.3923009049183982, Avg % of duplicate genes across participants 0.0204
# Generation 5170: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.0202
# Generation 5171: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.02
# Generation 5172: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.02
# Generation 5173: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.02
# Generation 5174: Min 16.0, Max 36.0, Avg 35.35, Std 2.9270292106502596, Avg % of duplicate genes across participants 0.02
# Generation 5175: Min 35.0, Max 36.0, Avg 35.91, Std 0.28618176042531507, Avg % of duplicate genes across participants 0.02
# Generation 5176: Min 34.0, Max 36.0, Avg 35.94, Std 0.34117444218480436, Avg % of duplicate genes across participants 0.02
# Generation 5177: Min 35.0, Max 36.0, Avg 35.93, Std 0.2551470164435192, Avg % of duplicate genes across participants 0.02
# Generation 5178: Min 35.0, Max 36.0, Avg 35.89, Std 0.31288975694321064, Avg % of duplicate genes across participants 0.02
# Generation 5179: Min 18.0, Max 36.0, Avg 35.09, Std 3.2713758573419525, Avg % of duplicate genes across participants 0.02
# Generation 5180: Min 18.0, Max 36.0, Avg 35.16, Std 3.517726538547326, Avg % of duplicate genes across participants 0.02
# Generation 5181: Min 33.0, Max 36.0, Avg 35.89, Std 0.4448595283905814, Avg % of duplicate genes across participants 0.0202
# Generation 5182: Min 34.0, Max 36.0, Avg 35.83, Std 0.401372644808114, Avg % of duplicate genes across participants 0.0202
# Generation 5183: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.0203
# Generation 5184: Min 35.0, Max 36.0, Avg 35.93, Std 0.2551470164435192, Avg % of duplicate genes across participants 0.0213
# Generation 5185: Min 17.0, Max 36.0, Avg 35.22, Std 3.3453848806976016, Avg % of duplicate genes across participants 0.0208
# Generation 5186: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.0208
# Generation 5187: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.0207
# Generation 5188: Min 34.0, Max 36.0, Avg 35.96, Std 0.24166091947166865, Avg % of duplicate genes across participants 0.0203
# Generation 5189: Min 17.0, Max 36.0, Avg 35.36, Std 2.751435988715722, Avg % of duplicate genes across participants 0.0206
# Generation 5190: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.0213
# Generation 5191: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.0206
# Generation 5192: Min 34.0, Max 36.0, Avg 35.92, Std 0.3059411708150712, Avg % of duplicate genes across participants 0.0208
# Generation 5193: Min 18.0, Max 36.0, Avg 35.38, Std 2.671254386987477, Avg % of duplicate genes across participants 0.0208
# Generation 5194: Min 27.0, Max 36.0, Avg 35.52, Std 1.3075167302944577, Avg % of duplicate genes across participants 0.0207
# Generation 5195: Min 18.0, Max 36.0, Avg 35.65, Std 1.829617446353221, Avg % of duplicate genes across participants 0.0204
# Generation 5196: Min 18.0, Max 36.0, Avg 35.26, Std 2.6518672666632566, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5197: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.02
# Generation 5198: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.02
# Generation 5199: Min 35.0, Max 36.0, Avg 35.85, Std 0.3570714214269005, Avg % of duplicate genes across participants 0.02
# Generation 5200: Min 35.0, Max 36.0, Avg 35.96, Std 0.1959591794224259, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5201: Min 16.0, Max 36.0, Avg 35.41, Std 2.8287629805270367, Avg % of duplicate genes across participants 0.0206
# Generation 5202: Min 33.0, Max 36.0, Avg 35.82, Std 0.6225752966509516, Avg % of duplicate genes across participants 0.021
# Generation 5203: Min 34.0, Max 36.0, Avg 35.52, Std 0.519230199429747, Avg % of duplicate genes across participants 0.0207
# Generation 5204: Min 33.0, Max 36.0, Avg 35.93, Std 0.38091993909476135, Avg % of duplicate genes across participants 0.0207
# Generation 5205: Min 34.0, Max 36.0, Avg 35.88, Std 0.3544009029331745, Avg % of duplicate genes across participants 0.0202
# Generation 5206: Min 34.0, Max 36.0, Avg 35.91, Std 0.4023679907749709, Avg % of duplicate genes across participants 0.02
# Generation 5207: Min 34.0, Max 36.0, Avg 35.9, Std 0.3872983346208591, Avg % of duplicate genes across participants 0.02
# Generation 5208: Min 9.0, Max 36.0, Avg 35.69, Std 2.7007221256545666, Avg % of duplicate genes across participants 0.02
# Generation 5209: Min 34.0, Max 36.0, Avg 35.94, Std 0.34117444218480436, Avg % of duplicate genes across participants 0.02
# Generation 5210: Min 32.0, Max 36.0, Avg 35.81, Std 0.7168681887206978, Avg % of duplicate genes across participants 0.02
# Generation 5211: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.02
# Generation 5212: Min 26.0, Max 36.0, Avg 35.7, Std 1.1445523142258365, Avg % of duplicate genes across participants 0.02
# Generation 5213: Min 18.0, Max 36.0, Avg 35.52, Std 2.5631230949760897, Avg % of duplicate genes across participants 0.02
# Generation 5214: Min 18.0, Max 36.0, Avg 35.61, Std 1.8324573664891086, Avg % of duplicate genes across participants 0.0202
# Generation 5215: Min 17.0, Max 36.0, Avg 35.24, Std 2.653752060762279, Avg % of duplicate genes across participants 0.0206
# Generation 5216: Min 34.0, Max 36.0, Avg 35.81, Std 0.4624932431936055, Avg % of duplicate genes across participants 0.0206
# Generation 5217: Min 34.0, Max 36.0, Avg 35.89, Std 0.3713488925524689, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5218: Min 35.0, Max 36.0, Avg 35.86, Std 0.34698703145797516, Avg % of duplicate genes across participants 0.0202
# Generation 5219: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5220: Min 33.0, Max 36.0, Avg 35.82, Std 0.6225752966509516, Avg % of duplicate genes across participants 0.0202
# Generation 5221: Min 16.0, Max 36.0, Avg 35.53, Std 2.677517506945537, Avg % of duplicate genes across participants 0.02
# Generation 5222: Min 34.0, Max 36.0, Avg 35.95, Std 0.259807621135104, Avg % of duplicate genes across participants 0.02
# Generation 5223: Min 33.0, Max 36.0, Avg 35.27, Std 0.8349251463453858, Avg % of duplicate genes across participants 0.02
# Generation 5224: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.02
# Generation 5225: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.02
# Generation 5226: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.02
# Generation 5227: Min 35.0, Max 36.0, Avg 35.89, Std 0.31288975694321064, Avg % of duplicate genes across participants 0.0202
# Generation 5228: Min 27.0, Max 36.0, Avg 35.87, Std 0.9127431182979612, Avg % of duplicate genes across participants 0.021
# Generation 5229: Min 35.0, Max 36.0, Avg 35.93, Std 0.2551470164435192, Avg % of duplicate genes across participants 0.0202
# Generation 5230: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.0202
# Generation 5231: Min 33.0, Max 36.0, Avg 35.91, Std 0.3766961640371524, Avg % of duplicate genes across participants 0.0202
# Generation 5232: Min 18.0, Max 36.0, Avg 35.54, Std 2.007087442041308, Avg % of duplicate genes across participants 0.0204
# Generation 5233: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5234: Min 34.0, Max 36.0, Avg 35.82, Std 0.40938978980916596, Avg % of duplicate genes across participants 0.020499999999999997
# Generation 5235: Min 30.0, Max 36.0, Avg 35.85, Std 0.7921489758876339, Avg % of duplicate genes across participants 0.0207
# Generation 5236: Min 35.0, Max 36.0, Avg 35.86, Std 0.34698703145797516, Avg % of duplicate genes across participants 0.0203
# Generation 5237: Min 31.0, Max 36.0, Avg 35.77, Std 0.881532756056059, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5238: Min 35.0, Max 36.0, Avg 35.96, Std 0.1959591794224259, Avg % of duplicate genes across participants 0.02
# Generation 5239: Min 34.0, Max 36.0, Avg 35.91, Std 0.34914180500238495, Avg % of duplicate genes across participants 0.02
# Generation 5240: Min 35.0, Max 36.0, Avg 35.9, Std 0.3000000000002425, Avg % of duplicate genes across participants 0.02
# Generation 5241: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.02
# Generation 5242: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.02
# Generation 5243: Min 35.0, Max 36.0, Avg 35.89, Std 0.31288975694321064, Avg % of duplicate genes across participants 0.02
# Generation 5244: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.0208
# Generation 5245: Min 33.0, Max 36.0, Avg 35.91, Std 0.44933283877349833, Avg % of duplicate genes across participants 0.021
# Generation 5246: Min 35.0, Max 36.0, Avg 35.92, Std 0.2712931993244851, Avg % of duplicate genes across participants 0.0208
# Generation 5247: Min 35.0, Max 36.0, Avg 35.8, Std 0.40000000000010233, Avg % of duplicate genes across participants 0.0203
# Generation 5248: Min 34.0, Max 36.0, Avg 35.94, Std 0.34117444218480436, Avg % of duplicate genes across participants 0.0207
# Generation 5249: Min 34.0, Max 36.0, Avg 35.86, Std 0.49030602688538927, Avg % of duplicate genes across participants 0.0216
# Generation 5250: Min 35.0, Max 36.0, Avg 35.91, Std 0.28618176042531507, Avg % of duplicate genes across participants 0.0213
# Generation 5251: Min 18.0, Max 36.0, Avg 35.28, Std 3.082466544830625, Avg % of duplicate genes across participants 0.0218
# Generation 5252: Min 18.0, Max 36.0, Avg 35.05, Std 3.9226904032819454, Avg % of duplicate genes across participants 0.0215
# Generation 5253: Min 33.0, Max 36.0, Avg 35.88, Std 0.45343136194993905, Avg % of duplicate genes across participants 0.022000000000000002
# Generation 5254: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.0215
# Generation 5255: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.021400000000000002
# Generation 5256: Min 34.0, Max 36.0, Avg 35.8, Std 0.42426406871200356, Avg % of duplicate genes across participants 0.021
# Generation 5257: Min 34.0, Max 36.0, Avg 35.86, Std 0.4004996878899926, Avg % of duplicate genes across participants 0.0218
# Generation 5258: Min 34.0, Max 36.0, Avg 35.91, Std 0.31921779399078243, Avg % of duplicate genes across participants 0.0215
# Generation 5259: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.021400000000000002
# Generation 5260: Min 33.0, Max 36.0, Avg 35.89, Std 0.4667976006792155, Avg % of duplicate genes across participants 0.0215
# Generation 5261: Min 34.0, Max 36.0, Avg 35.95, Std 0.2958039891547502, Avg % of duplicate genes across participants 0.0202
# Generation 5262: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5263: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.0204
# Generation 5264: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.021099999999999997
# Generation 5265: Min 34.0, Max 36.0, Avg 35.93, Std 0.2917190429163158, Avg % of duplicate genes across participants 0.020499999999999997
# Generation 5266: Min 18.0, Max 36.0, Avg 34.62, Std 4.326153025495079, Avg % of duplicate genes across participants 0.020499999999999997
# Generation 5267: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.0206
# Generation 5268: Min 27.0, Max 36.0, Avg 35.66, Std 1.060377291344996, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5269: Min 18.0, Max 36.0, Avg 35.76, Std 1.8006665432556048, Avg % of duplicate genes across participants 0.0202
# Generation 5270: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.0208
# Generation 5271: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.02
# Generation 5272: Min 34.0, Max 36.0, Avg 35.91, Std 0.31921779399078243, Avg % of duplicate genes across participants 0.02
# Generation 5273: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.0204
# Generation 5274: Min 32.0, Max 36.0, Avg 35.95, Std 0.40926763859336696, Avg % of duplicate genes across participants 0.020499999999999997
# Generation 5275: Min 35.0, Max 36.0, Avg 35.91, Std 0.28618176042531507, Avg % of duplicate genes across participants 0.0203
# Generation 5276: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.0202
# Generation 5277: Min 35.0, Max 36.0, Avg 35.86, Std 0.34698703145797516, Avg % of duplicate genes across participants 0.0202
# Generation 5278: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.0203
# Generation 5279: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.0204
# Generation 5280: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.02
# Generation 5281: Min 34.0, Max 36.0, Avg 35.8, Std 0.4472135955000088, Avg % of duplicate genes across participants 0.02
# Generation 5282: Min 18.0, Max 36.0, Avg 34.71, Std 4.193554578159179, Avg % of duplicate genes across participants 0.0202
# Generation 5283: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5284: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.02
# Generation 5285: Min 35.0, Max 36.0, Avg 35.96, Std 0.1959591794224259, Avg % of duplicate genes across participants 0.02
# Generation 5286: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5287: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.0202
# Generation 5288: Min 35.0, Max 36.0, Avg 35.93, Std 0.2551470164435192, Avg % of duplicate genes across participants 0.0204
# Generation 5289: Min 35.0, Max 36.0, Avg 35.96, Std 0.1959591794224259, Avg % of duplicate genes across participants 0.021
# Generation 5290: Min 35.0, Max 36.0, Avg 35.83, Std 0.3756327994202299, Avg % of duplicate genes across participants 0.0206
# Generation 5291: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.0208
# Generation 5292: Min 34.0, Max 36.0, Avg 35.91, Std 0.31921779399078243, Avg % of duplicate genes across participants 0.0204
# Generation 5293: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.020099999999999996
# Generation 5294: Min 35.0, Max 36.0, Avg 35.88, Std 0.32496153618523466, Avg % of duplicate genes across participants 0.021
# Generation 5295: Min 35.0, Max 36.0, Avg 35.96, Std 0.1959591794224259, Avg % of duplicate genes across participants 0.0204
# Generation 5296: Min 35.0, Max 36.0, Avg 35.9, Std 0.3000000000002425, Avg % of duplicate genes across participants 0.0204
# Generation 5297: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.0202
# Generation 5298: Min 34.0, Max 36.0, Avg 35.9, Std 0.3316624790357319, Avg % of duplicate genes across participants 0.02
# Generation 5299: Min 35.0, Max 36.0, Avg 35.9, Std 0.3000000000002425, Avg % of duplicate genes across participants 0.0206
# Generation 5300: Min 34.0, Max 36.0, Avg 35.81, Std 0.4624932431936055, Avg % of duplicate genes across participants 0.0217
# Generation 5301: Min 35.0, Max 36.0, Avg 35.88, Std 0.32496153618523466, Avg % of duplicate genes across participants 0.0217
# Generation 5302: Min 34.0, Max 36.0, Avg 35.95, Std 0.259807621135104, Avg % of duplicate genes across participants 0.0218
# Generation 5303: Min 35.0, Max 36.0, Avg 35.84, Std 0.3666060555963501, Avg % of duplicate genes across participants 0.0222
# Generation 5304: Min 35.0, Max 36.0, Avg 35.91, Std 0.28618176042531507, Avg % of duplicate genes across participants 0.021099999999999997
# Generation 5305: Min 18.0, Max 36.0, Avg 35.59, Std 2.522280713957043, Avg % of duplicate genes across participants 0.021099999999999997
# Generation 5306: Min 34.0, Max 36.0, Avg 35.97, Std 0.22158519806201055, Avg % of duplicate genes across participants 0.0203
# Generation 5307: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.0202
# Generation 5308: Min 35.0, Max 36.0, Avg 35.93, Std 0.2551470164435192, Avg % of duplicate genes across participants 0.0209
# Generation 5309: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.0207
# Generation 5310: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.0202
# Generation 5311: Min 27.0, Max 36.0, Avg 35.89, Std 0.9043782394551567, Avg % of duplicate genes across participants 0.02
# Generation 5312: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.02
# Generation 5313: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.02
# Generation 5314: Min 18.0, Max 36.0, Avg 35.37, Std 3.0745894034814105, Avg % of duplicate genes across participants 0.02
# Generation 5315: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.02
# Generation 5316: Min 18.0, Max 36.0, Avg 35.5, Std 2.535744466621206, Avg % of duplicate genes across participants 0.02
# Generation 5317: Min 34.0, Max 36.0, Avg 35.9, Std 0.3316624790357319, Avg % of duplicate genes across participants 0.0203
# Generation 5318: Min 33.0, Max 36.0, Avg 35.47, Std 0.7804485889538951, Avg % of duplicate genes across participants 0.0216
# Generation 5319: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.021099999999999997
# Generation 5320: Min 9.0, Max 36.0, Avg 35.05, Std 4.169832130913698, Avg % of duplicate genes across participants 0.022400000000000003
# Generation 5321: Min 34.0, Max 36.0, Avg 35.89, Std 0.3433656942677344, Avg % of duplicate genes across participants 0.0209
# Generation 5322: Min 33.0, Max 36.0, Avg 35.81, Std 0.5233545643250972, Avg % of duplicate genes across participants 0.0206
# Generation 5323: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.0202
# Generation 5324: Min 27.0, Max 36.0, Avg 35.76, Std 0.9499473669631232, Avg % of duplicate genes across participants 0.02
# Generation 5325: Min 18.0, Max 36.0, Avg 35.68, Std 2.0043951706187837, Avg % of duplicate genes across participants 0.02
# Generation 5326: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.02
# Generation 5327: Min 34.0, Max 36.0, Avg 35.81, Std 0.41701318923959213, Avg % of duplicate genes across participants 0.02
# Generation 5328: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.02
# Generation 5329: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.02
# Generation 5330: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.02
# Generation 5331: Min 35.0, Max 36.0, Avg 35.96, Std 0.1959591794224259, Avg % of duplicate genes across participants 0.02
# Generation 5332: Min 27.0, Max 36.0, Avg 35.76, Std 0.9499473669631232, Avg % of duplicate genes across participants 0.02
# Generation 5333: Min 18.0, Max 36.0, Avg 34.99, Std 3.9102301722532604, Avg % of duplicate genes across participants 0.02
# Generation 5334: Min 25.0, Max 36.0, Avg 35.87, Std 1.1104503590887693, Avg % of duplicate genes across participants 0.0204
# Generation 5335: Min 18.0, Max 36.0, Avg 35.58, Std 1.8664404624847404, Avg % of duplicate genes across participants 0.02
# Generation 5336: Min 34.0, Max 36.0, Avg 35.83, Std 0.44844174649582313, Avg % of duplicate genes across participants 0.0202
# Generation 5337: Min 33.0, Max 36.0, Avg 35.81, Std 0.4624932431936055, Avg % of duplicate genes across participants 0.0202
# Generation 5338: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.019
# Generation 5339: Min 34.0, Max 36.0, Avg 35.66, Std 0.5141984052875413, Avg % of duplicate genes across participants 0.0197
# Generation 5340: Min 18.0, Max 36.0, Avg 35.47, Std 2.0854495918147085, Avg % of duplicate genes across participants 0.0199
# Generation 5341: Min 27.0, Max 36.0, Avg 35.82, Std 0.9314504817756222, Avg % of duplicate genes across participants 0.0192
# Generation 5342: Min 35.0, Max 36.0, Avg 35.86, Std 0.34698703145797516, Avg % of duplicate genes across participants 0.019299999999999998
# Generation 5343: Min 35.0, Max 36.0, Avg 35.93, Std 0.2551470164435192, Avg % of duplicate genes across participants 0.0192
# Generation 5344: Min 35.0, Max 36.0, Avg 35.92, Std 0.2712931993244851, Avg % of duplicate genes across participants 0.0196
# Generation 5345: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.0195
# Generation 5346: Min 28.0, Max 36.0, Avg 35.68, Std 0.9474175425861668, Avg % of duplicate genes across participants 0.019299999999999998
# Generation 5347: Min 35.0, Max 36.0, Avg 35.89, Std 0.31288975694321064, Avg % of duplicate genes across participants 0.0191
# Generation 5348: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.0191
# Generation 5349: Min 33.0, Max 36.0, Avg 35.95, Std 0.3278719262148643, Avg % of duplicate genes across participants 0.019
# Generation 5350: Min 34.0, Max 36.0, Avg 35.65, Std 0.5545268253205775, Avg % of duplicate genes across participants 0.0182
# Generation 5351: Min 23.0, Max 36.0, Avg 35.71, Std 1.5766737138672355, Avg % of duplicate genes across participants 0.018000000000000002
# Generation 5352: Min 34.0, Max 36.0, Avg 35.86, Std 0.4004996878899926, Avg % of duplicate genes across participants 0.0177
# Generation 5353: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.0171
# Generation 5354: Min 17.0, Max 36.0, Avg 35.23, Std 2.8908649224756546, Avg % of duplicate genes across participants 0.0173
# Generation 5355: Min 35.0, Max 36.0, Avg 35.89, Std 0.31288975694321064, Avg % of duplicate genes across participants 0.0168
# Generation 5356: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.0159
# Generation 5357: Min 22.0, Max 36.0, Avg 35.79, Std 1.4162979912434073, Avg % of duplicate genes across participants 0.0163
# Generation 5358: Min 27.0, Max 36.0, Avg 35.63, Std 1.2934836682385968, Avg % of duplicate genes across participants 0.015700000000000002
# Generation 5359: Min 17.0, Max 36.0, Avg 35.45, Std 2.7179955849853434, Avg % of duplicate genes across participants 0.0158
# Generation 5360: Min 34.0, Max 36.0, Avg 35.96, Std 0.24166091947166865, Avg % of duplicate genes across participants 0.0158
# Generation 5361: Min 18.0, Max 36.0, Avg 34.99, Std 3.548224908316825, Avg % of duplicate genes across participants 0.0165
# Generation 5362: Min 19.0, Max 36.0, Avg 35.75, Std 1.7226433176952136, Avg % of duplicate genes across participants 0.0155
# Generation 5363: Min 33.0, Max 36.0, Avg 35.7, Std 0.5196152422704269, Avg % of duplicate genes across participants 0.0161
# Generation 5364: Min 18.0, Max 36.0, Avg 35.71, Std 1.8883590760233682, Avg % of duplicate genes across participants 0.015600000000000001
# Generation 5365: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.015700000000000002
# Generation 5366: Min 33.0, Max 36.0, Avg 35.95, Std 0.3278719262148643, Avg % of duplicate genes across participants 0.0158
# Generation 5367: Min 35.0, Max 36.0, Avg 35.78, Std 0.4142463035443115, Avg % of duplicate genes across participants 0.0166
# Generation 5368: Min 26.0, Max 36.0, Avg 35.62, Std 1.4749915253994712, Avg % of duplicate genes across participants 0.016200000000000003
# Generation 5369: Min 33.0, Max 36.0, Avg 35.96, Std 0.3136877428269328, Avg % of duplicate genes across participants 0.0165
# Generation 5370: Min 26.0, Max 36.0, Avg 35.84, Std 1.0268398122393578, Avg % of duplicate genes across participants 0.016
# Generation 5371: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.0151
# Generation 5372: Min 32.0, Max 36.0, Avg 35.84, Std 0.6118823416310715, Avg % of duplicate genes across participants 0.0149
# Generation 5373: Min 34.0, Max 36.0, Avg 35.98, Std 0.19899748742148488, Avg % of duplicate genes across participants 0.015
# Generation 5374: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.0132
# Generation 5375: Min 34.0, Max 36.0, Avg 35.85, Std 0.40926763859364473, Avg % of duplicate genes across participants 0.0131
# Generation 5376: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.013000000000000001
# Generation 5377: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.0125
# Generation 5378: Min 27.0, Max 36.0, Avg 35.91, Std 0.8954886933960471, Avg % of duplicate genes across participants 0.0139
# Generation 5379: Min 29.0, Max 36.0, Avg 35.59, Std 0.8496469855178387, Avg % of duplicate genes across participants 0.0137
# Generation 5380: Min 34.0, Max 36.0, Avg 35.88, Std 0.38157568056655705, Avg % of duplicate genes across participants 0.0146
# Generation 5381: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.014199999999999999
# Generation 5382: Min 34.0, Max 36.0, Avg 35.44, Std 0.7255342858888161, Avg % of duplicate genes across participants 0.0141
# Generation 5383: Min 34.0, Max 36.0, Avg 35.83, Std 0.401372644808114, Avg % of duplicate genes across participants 0.0143
# Generation 5384: Min 34.0, Max 36.0, Avg 35.89, Std 0.3713488925524689, Avg % of duplicate genes across participants 0.014499999999999999
# Generation 5385: Min 33.0, Max 36.0, Avg 35.91, Std 0.3766961640371524, Avg % of duplicate genes across participants 0.014199999999999999
# Generation 5386: Min 34.0, Max 36.0, Avg 35.89, Std 0.3433656942677344, Avg % of duplicate genes across participants 0.0139
# Generation 5387: Min 27.0, Max 36.0, Avg 35.64, Std 0.9748846085562871, Avg % of duplicate genes across participants 0.0141
# Generation 5388: Min 35.0, Max 36.0, Avg 35.92, Std 0.2712931993244851, Avg % of duplicate genes across participants 0.0138
# Generation 5389: Min 31.0, Max 36.0, Avg 35.82, Std 0.6982836100037931, Avg % of duplicate genes across participants 0.014199999999999999
# Generation 5390: Min 32.0, Max 36.0, Avg 35.78, Std 0.6415605972937456, Avg % of duplicate genes across participants 0.0123
# Generation 5391: Min 34.0, Max 36.0, Avg 35.92, Std 0.3370459909265773, Avg % of duplicate genes across participants 0.0118
# Generation 5392: Min 33.0, Max 36.0, Avg 35.8, Std 0.48989794855687696, Avg % of duplicate genes across participants 0.0124
# Generation 5393: Min 35.0, Max 36.0, Avg 35.81, Std 0.3923009049183982, Avg % of duplicate genes across participants 0.0125
# Generation 5394: Min 26.0, Max 36.0, Avg 35.15, Std 1.9150718002206197, Avg % of duplicate genes across participants 0.0132
# Generation 5395: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.0118
# Generation 5396: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.0116
# Generation 5397: Min 30.0, Max 36.0, Avg 35.57, Std 1.1511298797268796, Avg % of duplicate genes across participants 0.0108
# Generation 5398: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.0131
# Generation 5399: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.0124
# Generation 5400: Min 35.0, Max 36.0, Avg 35.93, Std 0.2551470164435192, Avg % of duplicate genes across participants 0.0128
# Generation 5401: Min 35.0, Max 36.0, Avg 35.96, Std 0.1959591794224259, Avg % of duplicate genes across participants 0.012199999999999999
# Generation 5402: Min 33.0, Max 36.0, Avg 35.87, Std 0.48280430818332276, Avg % of duplicate genes across participants 0.011899999999999999
# Generation 5403: Min 32.0, Max 36.0, Avg 35.81, Std 0.7306846104851964, Avg % of duplicate genes across participants 0.0123
# Generation 5404: Min 35.0, Max 36.0, Avg 35.91, Std 0.28618176042531507, Avg % of duplicate genes across participants 0.011699999999999999
# Generation 5405: Min 34.0, Max 36.0, Avg 35.81, Std 0.48363209157346176, Avg % of duplicate genes across participants 0.0123
# Generation 5406: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.0125
# Generation 5407: Min 32.0, Max 36.0, Avg 35.86, Std 0.49030602688538927, Avg % of duplicate genes across participants 0.0127
# Generation 5408: Min 33.0, Max 36.0, Avg 35.62, Std 0.5963220606352932, Avg % of duplicate genes across participants 0.0139
# Generation 5409: Min 34.0, Max 36.0, Avg 35.83, Std 0.44844174649582313, Avg % of duplicate genes across participants 0.0143
# Generation 5410: Min 33.0, Max 36.0, Avg 35.66, Std 0.73783466982802, Avg % of duplicate genes across participants 0.013300000000000001
# Generation 5411: Min 33.0, Max 36.0, Avg 35.93, Std 0.3536947836765124, Avg % of duplicate genes across participants 0.0128
# Generation 5412: Min 34.0, Max 36.0, Avg 35.82, Std 0.43312815655412534, Avg % of duplicate genes across participants 0.011899999999999999
# Generation 5413: Min 27.0, Max 36.0, Avg 35.56, Std 1.107429455992473, Avg % of duplicate genes across participants 0.0105
# Generation 5414: Min 17.0, Max 36.0, Avg 35.35, Std 2.7617928959282643, Avg % of duplicate genes across participants 0.01
# Generation 5415: Min 34.0, Max 36.0, Avg 35.97, Std 0.22158519806201055, Avg % of duplicate genes across participants 0.01
# Generation 5416: Min 35.0, Max 36.0, Avg 35.9, Std 0.3000000000002425, Avg % of duplicate genes across participants 0.01
# Generation 5417: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.01
# Generation 5418: Min 35.0, Max 36.0, Avg 35.82, Std 0.3841874542459856, Avg % of duplicate genes across participants 0.01
# Generation 5419: Min 32.0, Max 36.0, Avg 35.8, Std 0.5477225575053322, Avg % of duplicate genes across participants 0.011200000000000002
# Generation 5420: Min 34.0, Max 36.0, Avg 35.94, Std 0.2764054992219742, Avg % of duplicate genes across participants 0.0102
# Generation 5421: Min 34.0, Max 36.0, Avg 35.9, Std 0.3872983346208591, Avg % of duplicate genes across participants 0.01
# Generation 5422: Min 34.0, Max 36.0, Avg 35.79, Std 0.4311612227461404, Avg % of duplicate genes across participants 0.01
# Generation 5423: Min 16.0, Max 36.0, Avg 35.75, Std 1.9968725547715744, Avg % of duplicate genes across participants 0.01
# Generation 5424: Min 34.0, Max 36.0, Avg 35.96, Std 0.24166091947166865, Avg % of duplicate genes across participants 0.01
# Generation 5425: Min 30.0, Max 36.0, Avg 35.92, Std 0.6112282715971745, Avg % of duplicate genes across participants 0.01
# Generation 5426: Min 18.0, Max 36.0, Avg 35.26, Std 3.5259608619495686, Avg % of duplicate genes across participants 0.01
# Generation 5427: Min 18.0, Max 36.0, Avg 35.8, Std 1.8000000000000658, Avg % of duplicate genes across participants 0.01
# Generation 5428: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5429: Min 26.0, Max 36.0, Avg 35.76, Std 1.2257242756835975, Avg % of duplicate genes across participants 0.01
# Generation 5430: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5431: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5432: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5433: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5434: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5435: Min 27.0, Max 36.0, Avg 35.73, Std 0.9680392554024349, Avg % of duplicate genes across participants 0.01
# Generation 5436: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5437: Min 35.0, Max 36.0, Avg 35.92, Std 0.2712931993244851, Avg % of duplicate genes across participants 0.01
# Generation 5438: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5439: Min 31.0, Max 36.0, Avg 35.84, Std 0.6280127387242277, Avg % of duplicate genes across participants 0.0101
# Generation 5440: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.0102
# Generation 5441: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5442: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5443: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5444: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.0102
# Generation 5445: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.0111
# Generation 5446: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.01
# Generation 5447: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5448: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5449: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.01
# Generation 5450: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.011200000000000002
# Generation 5451: Min 18.0, Max 36.0, Avg 35.45, Std 2.523390576189076, Avg % of duplicate genes across participants 0.011200000000000002
# Generation 5452: Min 35.0, Max 36.0, Avg 35.88, Std 0.32496153618523466, Avg % of duplicate genes across participants 0.011899999999999999
# Generation 5453: Min 35.0, Max 36.0, Avg 35.95, Std 0.21794494717680415, Avg % of duplicate genes across participants 0.0108
# Generation 5454: Min 18.0, Max 36.0, Avg 35.78, Std 1.797665152357377, Avg % of duplicate genes across participants 0.0104
# Generation 5455: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.0116
# Generation 5456: Min 35.0, Max 36.0, Avg 35.9, Std 0.3000000000002425, Avg % of duplicate genes across participants 0.0104
# Generation 5457: Min 24.0, Max 36.0, Avg 35.8, Std 1.4282856857086368, Avg % of duplicate genes across participants 0.0102
# Generation 5458: Min 27.0, Max 36.0, Avg 35.66, Std 1.012126474310519, Avg % of duplicate genes across participants 0.0102
# Generation 5459: Min 27.0, Max 36.0, Avg 35.75, Std 0.9630680142129159, Avg % of duplicate genes across participants 0.0103
# Generation 5460: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.0105
# Generation 5461: Min 26.0, Max 36.0, Avg 35.89, Std 0.9989494481703491, Avg % of duplicate genes across participants 0.0104
# Generation 5462: Min 34.0, Max 36.0, Avg 35.91, Std 0.3766961640371524, Avg % of duplicate genes across participants 0.0102
# Generation 5463: Min 35.0, Max 36.0, Avg 35.87, Std 0.3363034344163893, Avg % of duplicate genes across participants 0.01
# Generation 5464: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5465: Min 34.0, Max 36.0, Avg 35.98, Std 0.19899748742148488, Avg % of duplicate genes across participants 0.01
# Generation 5466: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.01
# Generation 5467: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5468: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.01
# Generation 5469: Min 18.0, Max 36.0, Avg 35.73, Std 1.826773111253883, Avg % of duplicate genes across participants 0.01
# Generation 5470: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5471: Min 35.0, Max 36.0, Avg 35.94, Std 0.2374868417411099, Avg % of duplicate genes across participants 0.0103
# Generation 5472: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5473: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5474: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5475: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5476: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.01
# Generation 5477: Min 35.0, Max 36.0, Avg 35.98, Std 0.14000000000029364, Avg % of duplicate genes across participants 0.01
# Generation 5478: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5479: Min 35.0, Max 36.0, Avg 35.92, Std 0.2712931993244851, Avg % of duplicate genes across participants 0.01
# Generation 5480: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5481: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5482: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5483: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5484: Min 35.0, Max 36.0, Avg 35.99, Std 0.09949874370959984, Avg % of duplicate genes across participants 0.01
# Generation 5485: Min 36.0, Max 36.0, Avg 36.0, Std 0.0, Avg % of duplicate genes across participants 0.01
# Generation 5486: Min 35.0, Max 36.0, Avg 35.97, Std 0.17058722109223556, Avg % of duplicate genes across participants 0.01
# ...
# {0: "['v', 's']", 1: "['m', 'r', 'o']", 2: "['t', 'd', 'w']", 3: "['o', 'a', 'd']", 4: "['i']", 5: "['a', 'i', 's']", 6: "['e', 'd', 'o']", 7: "['j']", 8: "['g', 'u', 'h']", 9: "['o', 'e']", 10: "['l', 'e']", 11: "['d', 'l']", 12: "['h', 'i', 's']", 13: "['d', 'd']", 14: "['g', 'd']", 15: "['h', 'i']", 16: "['i', 'o']", 17: "['o']", 18: "['p', 't', 'h']", 19: "['t', 'i', 'i']", 20: "['j', 's']", 21: "['o', 't']", 22: "['n', 'r', 't']", 23: "['e', 't', 'v']", 24: "['e', 'c']", 25: "['e', 'd']", 26: "['l', 'o']", 27: "['a', 'a']", 28: "['n', 'h', 'e']", 29: "['m', 'i']", 30: "['n', 'c', 'n']", 31: "['t', 'i', 'p']", 32: "['e', 'k', 'o']", 33: "['t', 'a', 'n']", 34: "['m', 'o']", 35: "['t', 't']", 36: "['l', 'p', 'e']", 37: "['l', 'g']", 38: "['h', 's']", 39: "['t', 'm']", 40: "['n', 'n']", 41: "['o', 'c']", 42: "['f']", 43: "['s', 'r']", 44: "['n', 'h', 'r']", 45: "['m', 'e']", 46: "['r', 't']", 47: "['n', 'e']", 48: "['a', 'e', 'l']", 49: "['s', 'e', 'p']", 50: "['h', 'e', 'u']", 51: "['l']", 52: "['y']", 53: "['s', 'o', 'o']", 54: "['r', 'd']", 55: "['s', 'e', 'n']", 56: "['g', 'n', 't']", 57: "['d', 'w', 'o']", 58: "['a']", 59: "['d', 'i', 'a']", 60: "['i', 'e']", 61: "['t', 'o']", 62: "['a', 't']", 63: "['t', 'e']", 64: "['c']", 65: "['s', 'l', 'l']", 66: "['e', 'p']", 67: "['r', 's', 'o']", 68: "['p', 'l', 'a']", 69: "['g']", 70: "['m', 'u', 'r']", 71: "['t']", 72: "['a', 'w']", 73: "['a', 'o', 'n']", 74: "['f', 'o', 'c']", 75: "['l', 't']", 76: "['e', 'l']", 77: "['e']", 78: "['i', 'd', 'i']", 79: "['m', 'u']", 80: "['m', 'l', 'w']", 81: "['d', 'o', 'c']", 82: "['r']", 83: "['t', 'n']", 84: "['t', 'u', 'o']", 85: "['h', 'a', 'o']", 86: "['o', 'i', 'n']", 87: "['v', 'h']", 88: "['h']", 89: "['h', 'h', 'n']", 90: "['v', 'h', 'a']", 91: "['e', 't']", 92: "['n']", 93: "['e', 'a']", 94: "['s']", 95: "['n', 'o']", 96: "['i', 'a', 'e']", 97: "['e', 'n']", 98: "['a', 'h']", 99: "['i', 'f', 'a']"} (36.0,)
# {0: "['v', 's']", 1: "['m', 'r', 'o']", 2: "['t', 'd', 'w']", 3: "['o', 'a', 'd']", 4: "['i']", 5: "['a', 'i', 's']", 6: "['e', 'd', 'o']", 7: "['j']", 8: "['g', 'u', 'h']", 9: "['o', 'e']", 10: "['l', 'e']", 11: "['d', 'l']", 12: "['h', 'i', 's']", 13: "['d', 'd']", 14: "['g', 'd']", 15: "['h', 'i']", 16: "['i', 'o']", 17: "['o']", 18: "['p', 't', 'h']", 19: "['t', 'i', 'i']", 20: "['j', 's']", 21: "['o', 't']", 22: "['n', 'r', 't']", 23: "['e', 't', 'v']", 24: "['e', 'c']", 25: "['e', 'd']", 26: "['l', 'o']", 27: "['a', 'a']", 28: "['n', 'h', 'e']", 29: "['m', 'i']", 30: "['n', 'c', 'n']", 31: "['t', 'i', 'p']", 32: "['e', 'k', 'o']", 33: "['t', 'a', 'n']", 34: "['m', 'o']", 35: "['t', 't']", 36: "['l', 'p', 'e']", 37: "['l', 'g']", 38: "['h', 's']", 39: "['t', 'm']", 40: "['n', 'n']", 41: "['o', 'c']", 42: "['f']", 43: "['s', 'r']", 44: "['n', 'h', 'r']", 45: "['m', 'e']", 46: "['r', 't']", 47: "['n', 'e']", 48: "['a', 'e', 'l']", 49: "['s', 'e', 'p']", 50: "['h', 'e', 'u']", 51: "['l']", 52: "['y']", 53: "['s', 'o', 'o']", 54: "['r', 'd']", 55: "['s', 'e', 'n']", 56: "['g', 'n', 't']", 57: "['d', 'w', 'o']", 58: "['a']", 59: "['d', 'i', 'a']", 60: "['i', 'e']", 61: "['t', 'o']", 62: "['c', 'e']", 63: "['t', 'e']", 64: "['c']", 65: "['s', 'l', 'l']", 66: "['e', 'p']", 67: "['r', 's', 'o']", 68: "['p', 'l', 'a']", 69: "['g']", 70: "['m', 'u', 'r']", 71: "['t']", 72: "['a', 'w']", 73: "['a', 'o', 'n']", 74: "['f', 'o', 'c']", 75: "['l', 't']", 76: "['e', 'l']", 77: "['e']", 78: "['i', 'd', 'i']", 79: "['m', 'u']", 80: "['m', 'l', 'w']", 81: "['d', 'o', 'c']", 82: "['r']", 83: "['t', 'n']", 84: "['t', 'u', 'o']", 85: "['h', 'a', 'o']", 86: "['o', 'i', 'n']", 87: "['v', 'h']", 88: "['h']", 89: "['h', 'h', 'n']", 90: "['v', 'h', 'a']", 91: "['e', 't']", 92: "['n']", 93: "['e', 'a']", 94: "['s']", 95: "['n', 'o']", 96: "['i', 'a', 'e']", 97: "['e', 'n']", 98: "['a', 'h']", 99: "['i', 'f', 'a']"} (36.0,)
# {0: "['v', 's']", 1: "['m', 'r', 'o']", 2: "['t', 'd', 'w']", 3: "['o', 'a', 'd']", 4: "['i']", 5: "['a', 'i', 's']", 6: "['e', 'd', 'o']", 7: "['j']", 8: "['g', 'u', 'h']", 9: "['o', 'e']", 10: "['l', 'e']", 11: "['d', 'l']", 12: "['h', 'i', 's']", 13: "['d', 'd']", 14: "['g', 'd']", 15: "['h', 'i']", 16: "['i', 'o']", 17: "['o']", 18: "['p', 't', 'h']", 19: "['t', 'i', 'i']", 20: "['j', 's']", 21: "['o', 't']", 22: "['n', 'r', 't']", 23: "['e', 't', 'v']", 24: "['e', 'c']", 25: "['e', 'd']", 26: "['l', 'o']", 27: "['a', 'a']", 28: "['n', 'h', 'e']", 29: "['m', 'i']", 30: "['n', 'c', 'n']", 31: "['t', 'i', 'p']", 32: "['e', 'k', 'o']", 33: "['t', 'a', 'n']", 34: "['m', 'o']", 35: "['t', 't']", 36: "['l', 'p', 'e']", 37: "['l', 'g']", 38: "['h', 's']", 39: "['t', 'm']", 40: "['n', 'n']", 41: "['o', 'c']", 42: "['f']", 43: "['s', 'r']", 44: "['n', 'h', 'r']", 45: "['m', 'e']", 46: "['r', 't']", 47: "['n', 'e']", 48: "['a', 'e', 'l']", 49: "['s', 'e', 'p']", 50: "['h', 'e', 'u']", 51: "['l']", 52: "['y']", 53: "['s', 'o', 'o']", 54: "['r', 'd']", 55: "['s', 'e', 'n']", 56: "['g', 'n', 't']", 57: "['d', 'w', 'o']", 58: "['a']", 59: "['d', 'i', 'a']", 60: "['i', 'e']", 61: "['t', 'o']", 62: "['a', 't']", 63: "['t', 'e']", 64: "['c']", 65: "['s', 'l', 'l']", 66: "['e', 'p']", 67: "['r', 's', 'o']", 68: "['p', 'l', 'a']", 69: "['g']", 70: "['m', 'u', 'r']", 71: "['t']", 72: "['a', 'w']", 73: "['a', 'o', 'n']", 74: "['f', 'o', 'c']", 75: "['l', 't']", 76: "['e', 'l']", 77: "['e']", 78: "['i', 'd', 'i']", 79: "['m', 'u']", 80: "['m', 'l', 'w']", 81: "['d', 'o', 'c']", 82: "['r']", 83: "['t', 'n']", 84: "['t', 'u', 'o']", 85: "['h', 'a', 'o']", 86: "['o', 'i', 'n']", 87: "['v', 'h']", 88: "['h']", 89: "['h', 'h', 'n']", 90: "['v', 'h', 'a']", 91: "['e', 't']", 92: "['n']", 93: "['e', 'a']", 94: "['s']", 95: "['n', 'o']", 96: "['i', 'a', 'e']", 97: "['e', 'n']", 98: "['a', 'h']", 99: "['i', 'f', 'a']"} (36.0,)
# {0: "['v', 's']", 1: "['m', 'r', 'o']", 2: "['t', 'd', 'w']", 3: "['o', 'a', 'd']", 4: "['i']", 5: "['a', 'i', 's']", 6: "['e', 'd', 'o']", 7: "['j']", 8: "['g', 'u', 'h']", 9: "['o', 'e']", 10: "['l', 'e']", 11: "['d', 'l']", 12: "['h', 'i', 's']", 13: "['d', 'd']", 14: "['g', 'd']", 15: "['h', 'i']", 16: "['i', 'o']", 17: "['o']", 18: "['p', 't', 'h']", 19: "['t', 'i', 'i']", 20: "['j', 's']", 21: "['o', 't']", 22: "['n', 'r', 't']", 23: "['e', 't', 'v']", 24: "['e', 'c']", 25: "['e', 'd']", 26: "['l', 'o']", 27: "['a', 'a']", 28: "['n', 'h', 'e']", 29: "['m', 'i']", 30: "['n', 'c', 'n']", 31: "['t', 'i', 'p']", 32: "['e', 'k', 'o']", 33: "['t', 'a', 'n']", 34: "['m', 'o']", 35: "['t', 't']", 36: "['l', 'p', 'e']", 37: "['l', 'g']", 38: "['h', 's']", 39: "['t', 'm']", 40: "['n', 'n']", 41: "['o', 'c']", 42: "['f']", 43: "['s', 'r']", 44: "['n', 'h', 'r']", 45: "['m', 'e']", 46: "['r', 't']", 47: "['n', 'e']", 48: "['a', 'e', 'l']", 49: "['s', 'e', 'p']", 50: "['h', 'e', 'u']", 51: "['l']", 52: "['y']", 53: "['s', 'o', 'o']", 54: "['r', 'd']", 55: "['s', 'e', 'n']", 56: "['g', 'n', 't']", 57: "['d', 'w', 'o']", 58: "['a']", 59: "['d', 'i', 'a']", 60: "['i', 'e']", 61: "['t', 'o']", 62: "['a', 't']", 63: "['t', 'e']", 64: "['c']", 65: "['s', 'l', 'l']", 66: "['e', 'p']", 67: "['r', 's', 'o']", 68: "['p', 'l', 'a']", 69: "['g']", 70: "['m', 'u', 'r']", 71: "['t']", 72: "['a', 'w']", 73: "['a', 'o', 'n']", 74: "['f', 'o', 'c']", 75: "['l', 't']", 76: "['e', 'l']", 77: "['e']", 78: "['i', 'd', 'i']", 79: "['m', 'u']", 80: "['m', 'l', 'w']", 81: "['d', 'o', 'c']", 82: "['r']", 83: "['t', 'n']", 84: "['t', 'u', 'o']", 85: "['h', 'a', 'o']", 86: "['o', 'i', 'n']", 87: "['v', 'h']", 88: "['h']", 89: "['h', 'h', 'n']", 90: "['v', 'h', 'a']", 91: "['e', 't']", 92: "['n']", 93: "['e', 'a']", 94: "['s']", 95: "['n', 'o']", 96: "['i', 'a', 'e']", 97: "['e', 'n']", 98: "['a', 'h']", 99: "['i', 'f', 'a']"} (36.0,)
# {0: "['v', 's']", 1: "['m', 'r', 'o']", 2: "['t', 'd', 'w']", 3: "['o', 'a', 'd']", 4: "['i']", 5: "['a', 'i', 's']", 6: "['e', 'd', 'o']", 7: "['j']", 8: "['g', 'u', 'h']", 9: "['o', 'e']", 10: "['l', 'e']", 11: "['d', 'l']", 12: "['h', 'i', 's']", 13: "['d', 'd']", 14: "['g', 'd']", 15: "['h', 'i']", 16: "['i', 'o']", 17: "['o']", 18: "['p', 't', 'h']", 19: "['t', 'i', 'i']", 20: "['j', 's']", 21: "['o', 't']", 22: "['n', 'r', 't']", 23: "['e', 't', 'v']", 24: "['e', 'c']", 25: "['e', 'd']", 26: "['l', 'o']", 27: "['a', 'a']", 28: "['n', 'h', 'e']", 29: "['m', 'i']", 30: "['n', 'c', 'n']", 31: "['t', 'i', 'p']", 32: "['e', 'k', 'o']", 33: "['t', 'a', 'n']", 34: "['m', 'o']", 35: "['t', 't']", 36: "['l', 'p', 'e']", 37: "['l', 'g']", 38: "['h', 's']", 39: "['t', 'm']", 40: "['n', 'n']", 41: "['o', 'c']", 42: "['f']", 43: "['s', 'r']", 44: "['n', 'h', 'r']", 45: "['m', 'e']", 46: "['r', 't']", 47: "['n', 'e']", 48: "['a', 'e', 'l']", 49: "['s', 'e', 'p']", 50: "['h', 'e', 'u']", 51: "['l']", 52: "['y']", 53: "['s', 'o', 'o']", 54: "['r', 'd']", 55: "['s', 'e', 'n']", 56: "['g', 'n', 't']", 57: "['d', 'w', 'o']", 58: "['a']", 59: "['d', 'i', 'a']", 60: "['i', 'e']", 61: "['t', 'o']", 62: "['a', 't']", 63: "['t', 'e']", 64: "['c']", 65: "['s', 'l', 'l']", 66: "['e', 'p']", 67: "['r', 's', 'o']", 68: "['p', 'l', 'a']", 69: "['g']", 70: "['m', 'u', 'r']", 71: "['t']", 72: "['a', 'w']", 73: "['a', 'o', 'n']", 74: "['f', 'o', 'c']", 75: "['l', 't']", 76: "['e', 'l']", 77: "['e']", 78: "['i', 'd', 'i']", 79: "['m', 'u']", 80: "['m', 'l', 'w']", 81: "['d', 'o', 'c']", 82: "['r']", 83: "['t', 'n']", 84: "['t', 'u', 'o']", 85: "['h', 'a', 'o']", 86: "['o', 'i', 'n']", 87: "['v', 'h']", 88: "['h']", 89: "['h', 'h', 'n']", 90: "['v', 'h', 'a']", 91: "['e', 't']", 92: "['n']", 93: "['e', 'a']", 94: "['s']", 95: "['n', 'o']", 96: "['i', 'a', 'e']", 97: "['e', 'n']", 98: "['a', 'h']", 99: "['i', 'f', 'a']"} (36.0,)
# {0: "['v', 's']", 1: "['m', 'r', 'o']", 2: "['t', 'd', 'w']", 3: "['o', 'a', 'd']", 4: "['i']", 5: "['a', 'i', 's']", 6: "['e', 'd', 'o']", 7: "['j']", 8: "['g', 'u', 'h']", 9: "['o', 'e']", 10: "['l', 'e']", 11: "['d', 'l']", 12: "['h', 'i', 's']", 13: "['d', 'd']", 14: "['g', 'd']", 15: "['h', 'i']", 16: "['i', 'o']", 17: "['o']", 18: "['p', 't', 'h']", 19: "['t', 'i', 'i']", 20: "['j', 's']", 21: "['o', 't']", 22: "['n', 'r', 't']", 23: "['e', 't', 'v']", 24: "['e', 'c']", 25: "['e', 'd']", 26: "['l', 'o']", 27: "['a', 'a']", 28: "['n', 'h', 'e']", 29: "['m', 'i']", 30: "['n', 'c', 'n']", 31: "['t', 'i', 'p']", 32: "['e', 'k', 'o']", 33: "['t', 'a', 'n']", 34: "['m', 'o']", 35: "['t', 't']", 36: "['l', 'p', 'e']", 37: "['l', 'g']", 38: "['h', 's']", 39: "['t', 'm']", 40: "['n', 'n']", 41: "['o', 'c']", 42: "['f']", 43: "['s', 'r']", 44: "['n', 'h', 'r']", 45: "['m', 'e']", 46: "['r', 't']", 47: "['n', 'e']", 48: "['a', 'e', 'l']", 49: "['s', 'e', 'p']", 50: "['h', 'e', 'u']", 51: "['l']", 52: "['y']", 53: "['s', 'o', 'o']", 54: "['r', 'd']", 55: "['s', 'e', 'n']", 56: "['g', 'n', 't']", 57: "['q', 'h', 'e']", 58: "['a']", 59: "['d', 'i', 'a']", 60: "['i', 'e']", 61: "['t', 'o']", 62: "['a', 't']", 63: "['t', 'e']", 64: "['c']", 65: "['s', 'l', 'l']", 66: "['e', 'p']", 67: "['r', 's', 'o']", 68: "['p', 'l', 'a']", 69: "['g']", 70: "['m', 'u', 'r']", 71: "['t']", 72: "['a', 'w']", 73: "['a', 'o', 'n']", 74: "['f', 'o', 'c']", 75: "['l', 't']", 76: "['e', 'l']", 77: "['e']", 78: "['i', 'd', 'i']", 79: "['m', 'u']", 80: "['m', 'l', 'w']", 81: "['d', 'o', 'c']", 82: "['r']", 83: "['t', 'n']", 84: "['t', 'u', 'o']", 85: "['h', 'a', 'o']", 86: "['o', 'i', 'n']", 87: "['v', 'h']", 88: "['h']", 89: "['h', 'h', 'n']", 90: "['v', 'h', 'a']", 91: "['e', 't']", 92: "['n']", 93: "['e', 'a']", 94: "['s']", 95: "['n', 'o']", 96: "['i', 'a', 'e']", 97: "['e', 'n']", 98: "['a', 'h']", 99: "['i', 'f', 'a']"} (36.0,)
# {0: "['v', 's']", 1: "['m', 'r', 'o']", 2: "['t', 'd', 'w']", 3: "['o', 'a', 'd']", 4: "['i']", 5: "['a', 'i', 's']", 6: "['e', 'd', 'o']", 7: "['j']", 8: "['g', 'u', 'h']", 9: "['o', 'e']", 10: "['l', 'e']", 11: "['d', 'l']", 12: "['h', 'i', 's']", 13: "['d', 'd']", 14: "['g', 'd']", 15: "['h', 'i']", 16: "['i', 'o']", 17: "['o']", 18: "['p', 't', 'h']", 19: "['t', 'i', 'i']", 20: "['j', 's']", 21: "['o', 't']", 22: "['n', 'r', 't']", 23: "['e', 't', 'v']", 24: "['e', 'c']", 25: "['e', 'd']", 26: "['l', 'o']", 27: "['a', 'a']", 28: "['n', 'h', 'e']", 29: "['m', 'i']", 30: "['n', 'c', 'n']", 31: "['t', 'i', 'p']", 32: "['e', 'k', 'o']", 33: "['t', 'a', 'n']", 34: "['m', 'o']", 35: "['t', 't']", 36: "['l', 'p', 'e']", 37: "['l', 'g']", 38: "['h', 's']", 39: "['t', 'm']", 40: "['n', 'n']", 41: "['o', 'c']", 42: "['f']", 43: "['s', 'r']", 44: "['n', 'h', 'r']", 45: "['m', 'e']", 46: "['r', 't']", 47: "['n', 'e']", 48: "['a', 'e', 'l']", 49: "['s', 'e', 'p']", 50: "['h', 'e', 'u']", 51: "['l']", 52: "['y']", 53: "['s', 'o', 'o']", 54: "['r', 'd']", 55: "['s', 'e', 'n']", 56: "['g', 'n', 't']", 57: "['d', 'w', 'o']", 58: "['a']", 59: "['d', 'i', 'a']", 60: "['i', 'e']", 61: "['t', 'o']", 62: "['a', 't']", 63: "['t', 'e']", 64: "['c']", 65: "['s', 'l', 'l']", 66: "['e', 'p']", 67: "['r', 's', 'o']", 68: "['p', 'l', 'a']", 69: "['g']", 70: "['m', 'u', 'r']", 71: "['t']", 72: "['a', 'w']", 73: "['a', 'o', 'n']", 74: "['f', 'o', 'c']", 75: "['l', 't']", 76: "['e', 'l']", 77: "['e']", 78: "['i', 'd', 'i']", 79: "['m', 'u']", 80: "['m', 'l', 'w']", 81: "['d', 'o', 'c']", 82: "['r']", 83: "['t', 'n']", 84: "['t', 'u', 'o']", 85: "['h', 'a', 'o']", 86: "['o', 'i', 'n']", 87: "['v', 'h']", 88: "['h']", 89: "['h', 'h', 'n']", 90: "['v', 'h', 'a']", 91: "['e', 't']", 92: "['n']", 93: "['e', 'a']", 94: "['s']", 95: "['n', 'o']", 96: "['i', 'a', 'e']", 97: "['e', 'n']", 98: "['a', 'h']", 99: "['i', 'f', 'a']"} (36.0,)
# {0: "['v', 's']", 1: "['m', 'r', 'o']", 2: "['t', 'd', 'w']", 3: "['o', 'a', 'd']", 4: "['i']", 5: "['a', 'i', 's']", 6: "['e', 'd', 'o']", 7: "['j']", 8: "['g', 'u', 'h']", 9: "['o', 'e']", 10: "['l', 'e']", 11: "['d', 'l']", 12: "['h', 'i', 's']", 13: "['d', 'd']", 14: "['g', 'd']", 15: "['h', 'i']", 16: "['i', 'o']", 17: "['o']", 18: "['p', 't', 'h']", 19: "['t', 'i', 'i']", 20: "['j', 's']", 21: "['o', 't']", 22: "['n', 'r', 't']", 23: "['e', 't', 'v']", 24: "['e', 'c']", 25: "['e', 'd']", 26: "['l', 'o']", 27: "['a', 'a']", 28: "['n', 'h', 'e']", 29: "['m', 'i']", 30: "['n', 'c', 'n']", 31: "['t', 'i', 'p']", 32: "['e', 'k', 'o']", 33: "['t', 'a', 'n']", 34: "['m', 'o']", 35: "['t', 't']", 36: "['l', 'p', 'e']", 37: "['l', 'g']", 38: "['h', 's']", 39: "['t', 'm']", 40: "['n', 'n']", 41: "['o', 'c']", 42: "['f']", 43: "['s', 'r']", 44: "['n', 'h', 'r']", 45: "['m', 'e']", 46: "['r', 't']", 47: "['n', 'e']", 48: "['a', 'e', 'l']", 49: "['s', 'e', 'p']", 50: "['h', 'e', 'u']", 51: "['l']", 52: "['y']", 53: "['s', 'o', 'o']", 54: "['r', 'd']", 55: "['s', 'e', 'n']", 56: "['g', 'n', 't']", 57: "['d', 'w', 'o']", 58: "['a']", 59: "['d', 'i', 'a']", 60: "['i', 'e']", 61: "['t', 'o']", 62: "['a', 't']", 63: "['t', 'e']", 64: "['c']", 65: "['s', 'l', 'l']", 66: "['e', 'p']", 67: "['r', 's', 'o']", 68: "['p', 'l', 'a']", 69: "['g']", 70: "['m', 'u', 'r']", 71: "['t']", 72: "['a', 'w']", 73: "['a', 'o', 'n']", 74: "['f', 'o', 'c']", 75: "['l', 't']", 76: "['e', 'l']", 77: "['e']", 78: "['i', 'd', 'i']", 79: "['m', 'u']", 80: "['m', 'l', 'w']", 81: "['d', 'o', 'c']", 82: "['r']", 83: "['t', 'n']", 84: "['t', 'u', 'o']", 85: "['h', 'a', 'o']", 86: "['o', 'i', 'n']", 87: "['v', 'h']", 88: "['h']", 89: "['h', 'h', 'n']", 90: "['v', 'h', 'a']", 91: "['e', 't']", 92: "['n']", 93: "['e', 'a']", 94: "['s']", 95: "['n', 'o']", 96: "['i', 'a', 'e']", 97: "['e', 'n']", 98: "['a', 'h']", 99: "['i', 'f', 'a']"} (36.0,)

# %% [markdown]
# ### Final population

# %%
for ind in population:
    print(ind)
